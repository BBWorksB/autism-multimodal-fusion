# %% [markdown]
# # 00 — Environment Setup
#
# Verifies the Colab runtime environment, installs all project dependencies,
# and confirms access to the dataset on Google Drive.
#
# **Run this notebook once at the start of each new Colab session before
# opening any other notebook.**
#
# ## What this notebook does
# - Confirms GPU availability (A100 recommended for training)
# - Installs all required packages
# - Mounts Google Drive
# - Verifies dataset directory is accessible
#
# ## Note
# Dataset paths are configured for Google Drive.
# See README for full data setup instructions.

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

# %%
# Run this in your first notebook cell
# !pip install ultralytics torch torchvision torchaudio
# !pip install streamlit pandas numpy scikit-learn
# !pip install matplotlib seaborn plotly
# !pip install opencv-python-headless Pillow

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# data setup is covered in the README
import os
dataset_path = '/content/drive/MyDrive/Dataset'
print(os.listdir(dataset_path))
